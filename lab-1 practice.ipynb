# %% [markdown]
# # **datafram using csv**

# %%
df = spark.read.csv('/Volumes/workspace/default/apacha-data/MegaMart.csv', header=True, inferSchema=True)

# %%
display(df)

# %%
df.show()

# %%
df.printSchema()

# %%
df2 = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/Volumes/workspace/default/apacha-data/MegaMart.csv")

# %%
display(df2)

# %%
df3 = spark.read.csv('/Volumes/workspace/default/apacha-data/MegaMart.csv')

# %%
display(df3)

# %% [markdown]
# # **datafram using json**

# %%
df4 = spark.read.json("/Volumes/workspace/default/apacha-data/example1.json")

# %%
df4.show()

# %%
df5 = spark.read.json("/Volumes/workspace/default/apacha-data/example2.json", multiLine=True)

# %%
df5.show()

# %%
df5.printSchema()
